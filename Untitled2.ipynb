# %% [markdown]
# <a href="https://colab.research.google.com/github/ramana692/231FA04A56_MLOPS1/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Machine Learning
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-16146e86-6a21-47da-8b89-4d34c77d7d91" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-16146e86-6a21-47da-8b89-4d34c77d7d91">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv("Curriculum_Industry_Skill_Alignment_Synthetic_Dataset_500.csv")

# %%
df.head()
# Out:
#   Student_ID  Programming  DSA  DBMS  OS  Computer_Networks  OOP  \
# 0       S001            2    4     2   4                  4    4
# 1       S002            8    9    10   9                  8    8
# 2       S003            8    9     7   8                  7    9
# 3       S004            3    3     4   3                  2    3
# 4       S005            8    8     8   6                  8    7
#
#    Web_Development  Python  Java  ...  DevOps  SQL  Git_GitHub  Communication  \
# 0                2       4     3  ...       2    2           2              4
# 1               10       9     9  ...       8    9           8              8
# 2                8       9     9  ...       7    9           7              7
# 3                3       2     4  ...       4    4           2              4
# 4                6       6     6  ...       7    6           6              8
#
#    Teamwork  Problem_Solving  Internship  Certifications  \
# ...

# %%
df.tail()
# Out:
#     Student_ID  Programming  DSA  DBMS  OS  Computer_Networks  OOP  \
# 495       S496           10    8    10  10                  8    9
# 496       S497            4    3     3   5                  4    4
# 497       S498            5    6     5   5                  6    5
# 498       S499            5    5     7   5                  5    6
# 499       S500            8    6     7   8                  6    8
#
#      Web_Development  Python  Java  ...  DevOps  SQL  Git_GitHub  \
# 495               10       8     8  ...      10   10           9
# 496                4       3     4  ...       3    4           3
# 497                7       5     6  ...       6    6           6
# 498                5       7     7  ...       5    7           5
# 499                8       8     8  ...       6    7           8
#
#      Communication  Teamwork  Problem_Solving  Internship  Certifications  \
# 495             10         8               10         Yes               5
# ...

# %%
df.shape
# Out:
# (500, 22)

# %%
df.columns
# Out:
# Index(['Student_ID', 'Programming', 'DSA', 'DBMS', 'OS', 'Computer_Networks',
#        'OOP', 'Web_Development', 'Python', 'Java', 'AI_ML', 'Cloud_Computing',
#        'DevOps', 'SQL', 'Git_GitHub', 'Communication', 'Teamwork',
#        'Problem_Solving', 'Internship', 'Certifications',
#        'Industry_Alignment_Score', 'Employability_Status'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 22 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Student_ID                500 non-null    object
#  1   Programming               500 non-null    int64
#  2   DSA                       500 non-null    int64
#  3   DBMS                      500 non-null    int64
#  4   OS                        500 non-null    int64
#  5   Computer_Networks         500 non-null    int64
#  6   OOP                       500 non-null    int64
#  7   Web_Development           500 non-null    int64
#  8   Python                    500 non-null    int64
#  9   Java                      500 non-null    int64
#  10  AI_ML                     500 non-null    int64
#  11  Cloud_Computing           500 non-null    int64
#  12  DevOps                    500 non-null    int64
#  13  SQL                       500 non-null    int64
# ...

# %%
df.isnull().sum()
# Out:
# Student_ID                  0
# Programming                 0
# DSA                         0
# DBMS                        0
# OS                          0
# Computer_Networks           0
# OOP                         0
# Web_Development             0
# Python                      0
# Java                        0
# AI_ML                       0
# Cloud_Computing             0
# DevOps                      0
# SQL                         0
# Git_GitHub                  0
# Communication               0
# Teamwork                    0
# Problem_Solving             0
# Internship                  0
# Certifications              0
# Industry_Alignment_Score    0
# Employability_Status        0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.describe()
# Out:
#        Programming         DSA        DBMS        OS  Computer_Networks  \
# count   500.000000  500.000000  500.000000  500.0000         500.000000
# mean      6.496000    6.554000    6.498000    6.5540           6.568000
# std       2.064584    2.131706    2.100195    2.0995           2.105765
# min       2.000000    2.000000    2.000000    2.0000           2.000000
# 25%       5.000000    5.000000    5.000000    5.0000           5.000000
# 50%       7.000000    7.000000    7.000000    7.0000           7.000000
# 75%       8.000000    8.000000    8.000000    8.0000           8.000000
# max      10.000000   10.000000   10.000000   10.0000          10.000000
#
#              OOP  Web_Development      Python        Java       AI_ML  \
# count  500.00000       500.000000  500.000000  500.000000  500.000000
# mean     6.58000         6.526000    6.588000    6.562000    6.494000
# std      2.15334         2.116195    2.149301    2.091628    2.120131
# ...

# %%
encoder = LabelEncoder()

df["Internship"] = encoder.fit_transform(df["Internship"])

# %%
df = df.drop("Student_ID", axis=1)

# %%
X = df.drop("Employability_Status", axis=1)

y = df["Employability_Status"]

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42
)

# %%
model = DecisionTreeClassifier(random_state=42)

model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
y_pred = model.predict(X_test)

# %%
accuracy = accuracy_score(y_test, y_pred)

print("Accuracy :", accuracy)
# Out:
# Accuracy : 1.0

# %%
cm = confusion_matrix(y_test, y_pred)

print(cm)
# Out:
# [[42  0]
#  [ 0 58]]

# %%
plt.figure(figsize=(6,5))

sns.heatmap(cm,
            annot=True,
            cmap="Blues",
            fmt="d")

plt.xlabel("Predicted")

plt.ylabel("Actual")

plt.title("Confusion Matrix")

plt.show()

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        42
#            1       1.00      1.00      1.00        58
#
#     accuracy                           1.00       100
#    macro avg       1.00      1.00      1.00       100
# weighted avg       1.00      1.00      1.00       100

# %%
importance = pd.DataFrame({

    'Feature': X.columns,

    'Importance': model.feature_importances_

})

importance = importance.sort_values(
    by='Importance',
    ascending=False
)

print(importance)
# Out:
#                      Feature  Importance
# 19  Industry_Alignment_Score         1.0
# 0                Programming         0.0
# 2                       DBMS         0.0
# 1                        DSA         0.0
# 3                         OS         0.0
# 4          Computer_Networks         0.0
# 6            Web_Development         0.0
# 5                        OOP         0.0
# 8                       Java         0.0
# 9                      AI_ML         0.0
# 10           Cloud_Computing         0.0
# 7                     Python         0.0
# 11                    DevOps         0.0
# 12                       SQL         0.0
# 14             Communication         0.0
# 13                Git_GitHub         0.0
# 15                  Teamwork         0.0
# 16           Problem_Solving         0.0
# 17                Internship         0.0
# 18            Certifications         0.0

# %%
plt.figure(figsize=(10,6))

sns.barplot(
    x='Importance',
    y='Feature',
    data=importance
)

plt.title("Feature Importance")

plt.show()

# %%
sns.countplot(
    x='Employability_Status',
    data=df
)

plt.title("Employability Distribution")

plt.show()

# %%
import joblib

joblib.dump(
    model,
    "Employability_Model.pkl"
)
# Out:
# ['Employability_Model.pkl']

# %%
new_student = [[

8,8,7,8,7,8,8,9,8,7,7,6,8,8,8,9,9,1,3,85

]]

prediction = model.predict(new_student)

print(prediction)
# Out:
# [1]
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
